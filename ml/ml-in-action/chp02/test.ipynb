# %%
import KNN

group, labels = KNN.create_data_set()
print(group)
print(labels)
KNN.classify0([0, 0], group, labels, 3)
# Out:
# [[1.  1.1]
#  [1.  1. ]
#  [0.  0. ]
#  [0.  0.1]]
# ['A', 'A', 'B', 'B']
# 'B'

# %%
from imp import reload 
reload(KNN)

labes = {'largeDoses': 1, 'smallDoses': 2, 'didntLike': 3}
datingLabels = []
datingDataMat,datingLabels2 = KNN.file2matrix('datingTestSet.txt')

for key in datingLabels2:
    datingLabels.append(labes[key])
KNN.file2matrix("datingTestSet2.txt")
import matplotlib
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.scatter(datingDataMat[:, 1], datingDataMat[:, 2])
plt.show()

# %%
from numpy import *
fig2 = plt.figure()
ax2 = fig2.add_subplot(1, 1, 1)
ax2.scatter(datingDataMat[:, 1], datingDataMat[:, 2], 10.0*array(datingLabels), 100.0*array(datingLabels), marker=".")
plt.show()

# %%
tempmat = mat(random.rand(4,4))
tempmat
# Out:
# matrix([[0.38156948, 0.3790805 , 0.19059271, 0.6339195 ],
#         [0.58573111, 0.42154469, 0.6105925 , 0.4830348 ],
#         [0.8819512 , 0.32774592, 0.31299056, 0.45145982],
#         [0.09045878, 0.72112669, 0.21960885, 0.28114382]])

# %%
tempmat.min(0)
# Out:
# matrix([[0.09045878, 0.32774592, 0.19059271, 0.28114382]])

# %%
tempmat.min(1)
# Out:
# matrix([[0.19059271],
#         [0.42154469],
#         [0.31299056],
#         [0.09045878]])

# %%
tempmat.min()
# Out:
# 0.09045877733812913

# %%
reload(KNN)
normMat, ranges, minVals = KNN.autoNorm(datingDataMat)
normMat
# Out:
# array([[0.44832535, 0.39805139, 0.56233353],
#        [0.15873259, 0.34195467, 0.98724416],
#        [0.28542943, 0.06892523, 0.47449629],
#        ...,
#        [0.29115949, 0.50910294, 0.51079493],
#        [0.52711097, 0.43665451, 0.4290048 ],
#        [0.47940793, 0.3768091 , 0.78571804]])

# %%
ranges
# Out:
# array([9.1273000e+04, 2.0919349e+01, 1.6943610e+00])

# %%
minVals
# Out:
# array([0.      , 0.      , 0.001156])

# %%
raw_input()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-a212d1ec56ec> in <module>
# ----> 1 raw_input()
#
# NameError: name 'raw_input' is not defined

# %%
input()
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-76-9c8b639daf2f> in <module>
# ----> 1 input()
#
# g:\programming\python3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
